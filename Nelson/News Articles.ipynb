# %%
import pandas
import requests
import json
from api_keys import api_key

# %%
#Building base url
url = "https://newsapi.org/v2/everything?qInTitle="
query = ["Contro", "Old Town Road", "Wrecking Ball"]

response_list = []

#Build response json with loop

for video in query:
    response = requests.get(url + video + "&apiKey=" + api_key)
    response_json = response.json()
    response_list.append(response_json)
    
    
    
response_list
# Out:
# [{'status': 'ok', 'totalResults': 0, 'articles': []},
#  {'status': 'ok',
#   'totalResults': 93,
#   'articles': [{'source': {'id': 'mashable', 'name': 'Mashable'},
#     'author': 'Sage Anderson',
#     'title': "Uber driver plays his own 'Old Town Road' remix dedicated to his cat",
#     'description': 'We\'re officially on our millionth "Old Town Road" remix, and Lil Nas X isn\'t even featured this time. Twitter user @justjordinjames posted a video of their very yeehaw-filled Uber ride last week. But instead of getting the horses in the back, this driver just…',
#     'url': 'https://mashable.com/article/uber-driver-old-town-road-cat-remix/',
#     'urlToImage': 'https://mondrian.mashable.com/2019%252F09%252F04%252F53%252Feddf43a7af3946a4a3e37082a0abe57e.e049b.jpg%252F1200x630.jpg?signature=hLhxVXVfVrsrmQ1wSX5o7pkNF9Q=',
#     'publishedAt': '2019-09-04T14:52:53Z',
# ...
